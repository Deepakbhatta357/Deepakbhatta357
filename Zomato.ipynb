# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepakbhatta357/Deepakbhatta357/blob/main/Zomato.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/Zomato data .csv')
df.head(1)
# Out:
#     name online_order book_table   rate  votes  approx_cost(for two people)  \
# 0  Jalsa          Yes        Yes  4.1/5    775                          800
#
#   listed_in(type)
# 0          Buffet

# %%
df['online_order'].value_counts()
# Out:
# online_order
# No     90
# Yes    58
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'votes',
#        'approx_cost(for two people)', 'listed_in(type)'],
#       dtype='object')

# %%
import numpy as np
import seaborn as sns

# %%
df.shape
# Out:
# (148, 7)

# %%
df.head(1)
# Out:
#     name online_order book_table  rate  votes  approx_cost(for two people)  \
# 0  Jalsa          Yes        Yes   NaN    775                          800
#
#   listed_in(type)
# 0          Buffet

# %%
def handleRate(value):
  value=str(value).split('/')
  value=value[0];
  return float(value)
df['rate']=df['rate'].apply(handleRate)
df.head(3)
# Out:
#               name online_order book_table  rate  votes  \
# 0            Jalsa          Yes        Yes   NaN    775
# 1   Spice Elephant          Yes         No   NaN    787
# 2  San Churro Cafe          Yes         No   NaN    918
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet

# %%
def handleRate(value):
    try:
        return float(str(value).split('/')[0])  # Extract first part and convert to float
    except ValueError:
        return None  # Handle cases where conversion fails

df['rate'] = df['rate'].apply(handleRate)  # Apply the function to the column

# %%
df.head(3)
# Out:
#               name online_order book_table  rate  votes  \
# 0            Jalsa          Yes        Yes   NaN    775
# 1   Spice Elephant          Yes         No   NaN    787
# 2  San Churro Cafe          Yes         No   NaN    918
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet

# %%
new_df=pd.read_csv('/content/Zomato data .csv')

# %%
new_df.head()
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
new_df['rate']=new_df['rate'].str.split('/').str.get(0)

# %%
new_df['rate']=new_df['rate'].astype(float)

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    float64
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 8.2+ KB

# %%
new_df.head(3)
# Out:
#               name online_order book_table  rate  votes  \
# 0            Jalsa          Yes        Yes   4.1    775
# 1   Spice Elephant          Yes         No   4.1    787
# 2  San Churro Cafe          Yes         No   3.8    918
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet

# %%
sns.countplot(x=new_df['listed_in(type)'])
plt.xlabel('Type of Restaurant')
# plt.ylabel('Count')
# plt.title('Count of Restaurants by Type
# Out:
# Text(0.5, 0, 'Type of Restaurant')

# %%
sns.countplot(x=new_df['rate'])
plt.xlabel("Rating")
# Out:
# Text(0.5, 0, 'Rating')

# %%
groupeddata=new_df.groupby('listed_in(type)')['votes'].sum()
# groupeddata
plt.plot(groupeddata,marker='*',color='black')

# %%
plt.hist(new_df['rate'],bins=35)
plt.show()

# %%
new_df.head(3)
# Out:
#               name online_order book_table  rate  votes  \
# 0            Jalsa          Yes        Yes   4.1    775
# 1   Spice Elephant          Yes         No   4.1    787
# 2  San Churro Cafe          Yes         No   3.8    918
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet

# %%
new_df['approx_cost(for two people)']

sns.countplot(x=new_df['approx_cost(for two people)'])
# Out:
# <Axes: xlabel='approx_cost(for two people)', ylabel='count'>

# %%
new_df.head(3)
# Out:
#               name online_order book_table  rate  votes  \
# 0            Jalsa          Yes        Yes   4.1    775
# 1   Spice Elephant          Yes         No   4.1    787
# 2  San Churro Cafe          Yes         No   3.8    918
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet

# %%
group=new_df.groupby('online_order')['rate'].sum()
group

sns.boxplot(x='online_order',y='rate',data=new_df)
# Out:
# <Axes: xlabel='online_order', ylabel='rate'>

# %%
new_df.head(3)
# Out:
#               name online_order book_table  rate  votes  \
# 0            Jalsa          Yes        Yes   4.1    775
# 1   Spice Elephant          Yes         No   4.1    787
# 2  San Churro Cafe          Yes         No   3.8    918
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet

# %%
pivot_table=new_df.pivot_table(index='listed_in(type)',columns='online_order',values='rate',aggfunc='mean')
pivot_table
sns.heatmap(pivot_table,annot=True)
plt.show()
